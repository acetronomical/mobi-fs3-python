# %% [markdown]
# # <a id="#">Task 4 – Edge detection: Derivative operators</a>

# %%
import numpy
import matplotlib.pyplot as plt
import skimage.io

# %% [markdown]
# ---
#
# ## Prewitt filters
#
# **<a id="#">Task 4.1.1.</a>** Load the image `data/astronaut.png` and show it:

# %%
img = plt.imread('data/astronaut.png')
plt.figure(figsize=(13,5))
plt.imshow(img, 'gray')
plt.colorbar()

# %% [markdown]
# **<a id="#">Task 4.1.2.</a>** Implement horizontal and vertical 3&times;3 Prewitt filters:

# %%
def prewitt_h(img):
    img_copy = img.copy()
    for p in numpy.ndindex(img.shape):
        neighbourhood_sum = 0
        for q in numpy.ndindex(3, 3):
            i,j = p[0] + q[0] -1, p[1] + q[1] -1
            if 0 <= i <img.shape[0] and 0 <=j<img.shape[1]:
                neighbourhood_sum+=img[i,j] * (q[0] -1) * 1/6
        img_copy[p] = neighbourhood_sum
    return img_copy

    
def prewitt_v(img):
    img_copy = img.copy()
    for x,y in numpy.ndindex(img.shape):
        neighbourhood_sum = 0
        for f_x_v, f_y_v in numpy.ndindex(3, 3):
            f_x = f_x_v -1
            f_y = f_y_v + 1
            absolut_x = f_x + x
            absolut_y = f_y + y
            if 0 <= absolut_x <img.shape[0] and 0 <=absolut_y<img.shape[1]:
                neighbourhood_sum+=img[absolut_x,absolut_y] * (f_x) * 1/6
        img_copy[x,y] = neighbourhood_sum
    return img_copy

# %% [markdown]
# **<a id="#">Task 4.1.3.</a>** Test your above solution using the functions `prewitt_h` and `prewitt_v` for the previously loaded image and show the result:

# %%
img_h = prewitt_h(img)
plt.figure(figsize=(15,8))
plt.imshow(img_h)

img_v = prewitt_v(img)
plt.figure(figsize=(15,8))
plt.imshow(img_v)

# %% [markdown]
# **<a id="#">Task 4.1.4.</a>** Compare your results with the correct result image `data/astronaut_prewitt_h.tiff` and `data/astronaut_prewitt_v.tiff`:

# %%
img_ht =skimage.io.imread('data/astronaut_prewitt_h.tiff')
plt.figure(figsize=(13,5))
plt.imshow(img_ht)

img_vt =skimage.io.imread('data/astronaut_prewitt_v.tiff')
plt.figure(figsize=(13,5))
plt.imshow(img_vt)

#assert numpy.allclose(img_ht, img_h, atol=1e-4)

# %% [markdown]
# ---
#
# ## Edge detection
#
# **<a id="#">Task 4.2.1.</a>** Use your results from **Task 4.1.2 – 4.1.3** to compute the *gradient magnitude* of the image:

# %%
def prewitt_h(img):
    img_copy = img.copy()
    for p in numpy.ndindex(img.shape):
        neighbourhood_sum = 0
        for q in numpy.ndindex(3, 3):
            i,j = p[0] + q[0] -1, p[1] + q[1] -1
            if 0 <= i <img.shape[0] and 0 <=j<img.shape[1]:
                neighbourhood_sum+=img[i,j] * (q[0] -1) * 1/6
        img_copy[p] = numpy.sqrt(neighbourhood_sum)
    return img_copy

img_h = prewitt_h(img)
plt.figure(figsize=(15,8))
plt.imshow(img_h)
# Out:
# /tmp/ipykernel_13029/3444834873.py:9: RuntimeWarning: invalid value encountered in sqrt
#   img_copy[p] = numpy.sqrt(neighbourhood_sum)

# %% [markdown]
# **<a id="#">Task 4.2.2.</a>** Compare your result with the correct result image `data/astronaut_prewitt_gradmag.tiff`:

# %%
img_g =skimage.io.imread('data/astronaut_prewitt_gradmag.tiff')
plt.figure(figsize=(13,5))
plt.imshow(img_g)

# %% [markdown]
# ---
#
# ## Sobel filters (bonus)
#
# **<a id="#">Task 4.3.1.</a>** Implement the two functions `sobel_h` and `sobel_v` for horizontal and vertical 3&times;3 Sobel filtering, respectively:

# %% [markdown]
# **<a id="#">Task 4.3.2.</a>** Test your above solution using the functions `sobel_h` and `sobel_v` for the previously loaded image and show the result:

# %% [markdown]
# **<a id="#">Task 4.3.3.</a>** Compare your results with the correct result image `data/astronaut_sobel_h.tiff` and `data/astronaut_sobel_v.tiff`:
